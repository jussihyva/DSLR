# %%
# Import packages
import os

import matplotlib.pyplot as plt
import pandas as pd
import earthpy as et

# %%
# URL for .csv with avg monthly precip data
avg_monthly_precip_url = "https://ndownloader.figshare.com/files/12710618"

# Download file
et.data.get_data(url=avg_monthly_precip_url)
# Out:
# Downloading from https://ndownloader.figshare.com/files/12710618
# '/Users/jkauppi/earth-analytics/data/earthpy-downloads/avg-precip-months-seasons.csv'

# %%
# Set working directory to earth-analytics
os.chdir(os.path.join(et.io.HOME,
                      "earth-analytics",
                      "data"))

# %%
# Import data from .csv file
fname = os.path.join("earthpy-downloads",
                     "avg-precip-months-seasons.csv")

avg_monthly_precip = pd.read_csv(fname)

avg_monthly_precip
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 2     Mar    1.85  Spring
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring
# 5    June    2.02  Summer
# 6    July    1.93  Summer
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
# See first 5 rows
avg_monthly_precip.head()
# Out:
#   months  precip seasons
# 0    Jan    0.70  Winter
# 1    Feb    0.75  Winter
# 2    Mar    1.85  Spring
# 3    Apr    2.93  Spring
# 4    May    3.05  Spring

# %%
# See last 5 rows
avg_monthly_precip.tail()
# Out:
#    months  precip seasons
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
# Information about the dataframe
avg_monthly_precip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   months   12 non-null     object
#  1   precip   12 non-null     float64
#  2   seasons  12 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 416.0+ bytes

# %%
# Get column names
avg_monthly_precip.columns
# Out:
# Index(['months', 'precip', 'seasons'], dtype='object')

# %%
# Number of rows and columns
avg_monthly_precip.shape
# Out:
# (12, 3)

# %%
# Summary stats of all numeric columns
avg_monthly_precip.describe()
# Out:
#           precip
# count  12.000000
# mean    1.685833
# std     0.764383
# min     0.700000
# 25%     1.192500
# 50%     1.730000
# 75%     1.952500
# max     3.050000

# %%
# Median of all numeric columns
avg_monthly_precip.median()
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n0000j_w0004_q/T/ipykernel_11195/1422516315.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_monthly_precip.median()
# precip    1.73
# dtype: float64

# %%
# Median of numeric columns
avg_monthly_precip[["precip"]].median()
# Out:
# precip    1.73
# dtype: float64

# %%
# Sum of all numeric columns
avg_monthly_precip.sum()
# Out:
# months               JanFebMarAprMayJuneJulyAugSeptOctNovDec
# precip                                                 20.23
# seasons    WinterWinterSpringSpringSpringSummerSummerSumm...
# dtype: object

# %%
# Max of all numeric columns
avg_monthly_precip.max()
# Out:
# months       Sept
# precip       3.05
# seasons    Winter
# dtype: object

# %%
# Max of precip and seasons columns
avg_monthly_precip[["precip", "seasons"]].max()
# Out:
# precip       3.05
# seasons    Winter
# dtype: object

# %%
# Summary stats on precip column as dataframe
avg_monthly_precip[["precip"]].describe()
# Out:
#           precip
# count  12.000000
# mean    1.685833
# std     0.764383
# min     0.700000
# 25%     1.192500
# 50%     1.730000
# 75%     1.952500
# max     3.050000

# %%
# Summary stats on precip column as series
avg_monthly_precip["precip"].describe()
# Out:
# count    12.000000
# mean      1.685833
# std       0.764383
# min       0.700000
# 25%       1.192500
# 50%       1.730000
# 75%       1.952500
# max       3.050000
# Name: precip, dtype: float64

# %%
# Sort in descending order for precip
avg_monthly_precip.sort_values(by="precip",
                               ascending=True)
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 11    Dec    0.84  Winter
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 2     Mar    1.85  Spring
# 6    July    1.93  Summer
# 5    June    2.02  Summer
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring

# %%
avg_monthly_precip.sort_values(by="months")
# Out:
#    months  precip seasons
# 3     Apr    2.93  Spring
# 7     Aug    1.62  Summer
# 11    Dec    0.84  Winter
# 1     Feb    0.75  Winter
# 0     Jan    0.70  Winter
# 6    July    1.93  Summer
# 5    June    2.02  Summer
# 2     Mar    1.85  Spring
# 4     May    3.05  Spring
# 10    Nov    1.39    Fall
# 9     Oct    1.31    Fall
# 8    Sept    1.84    Fall

# %%
# Convert values from inches to millimeters
avg_monthly_precip["precip"] *= 25.4

avg_monthly_precip
# Out:
#    months  precip seasons
# 0     Jan  17.780  Winter
# 1     Feb  19.050  Winter
# 2     Mar  46.990  Spring
# 3     Apr  74.422  Spring
# 4     May  77.470  Spring
# 5    June  51.308  Summer
# 6    July  49.022  Summer
# 7     Aug  41.148  Summer
# 8    Sept  46.736    Fall
# 9     Oct  33.274    Fall
# 10    Nov  35.306    Fall
# 11    Dec  21.336  Winter

# %%
# Create new column with precip in the original units (inches)
avg_monthly_precip["precip_in"] = avg_monthly_precip["precip"] / 25.4

avg_monthly_precip
# Out:
#    months  precip seasons  precip_in
# 0     Jan  17.780  Winter       0.70
# 1     Feb  19.050  Winter       0.75
# 2     Mar  46.990  Spring       1.85
# 3     Apr  74.422  Spring       2.93
# 4     May  77.470  Spring       3.05
# 5    June  51.308  Summer       2.02
# 6    July  49.022  Summer       1.93
# 7     Aug  41.148  Summer       1.62
# 8    Sept  46.736    Fall       1.84
# 9     Oct  33.274    Fall       1.31
# 10    Nov  35.306    Fall       1.39
# 11    Dec  21.336  Winter       0.84

# %%
# Plot the data
f, ax = plt.subplots()

ax.bar(x=avg_monthly_precip.months,
       height=avg_monthly_precip.precip,
       color="blue")

ax.set(title="Plot of Average Monthly Precipitation in mm")
plt.show()

# %%
# Group data by seasons and summarize precip
precip_by_season=avg_monthly_precip.groupby(["seasons"])["precip"].describe()
precip_by_season
# Out:
#          count       mean        std     min     25%     50%     75%     max
# seasons
# Fall       3.0  38.438667   7.257173  33.274  34.290  35.306  41.021  46.736
# Spring     3.0  66.294000  16.787075  46.990  60.706  74.422  75.946  77.470
# Summer     3.0  47.159333   5.329967  41.148  45.085  49.022  50.165  51.308
# Winter     3.0  19.388667   1.802028  17.780  18.415  19.050  20.193  21.336

# %%
# Group data by seasons and summarize precip
precip_by_season=avg_monthly_precip.groupby(["seasons"])[["precip"]].describe()
precip_by_season
# Out:
#         precip
#          count      mean       std   min    25%   50%    75%   max
# seasons
# Fall       3.0  1.513333  0.285715  1.31  1.350  1.39  1.615  1.84
# Spring     3.0  2.610000  0.660908  1.85  2.390  2.93  2.990  3.05
# Summer     3.0  1.856667  0.209841  1.62  1.775  1.93  1.975  2.02
# Winter     3.0  0.763333  0.070946  0.70  0.725  0.75  0.795  0.84

# %%
precip_by_season.columns
# Out:
# MultiIndex([('precip', 'count'),
#             ('precip',  'mean'),
#             ('precip',   'std'),
#             ('precip',   'min'),
#             ('precip',   '25%'),
#             ('precip',   '50%'),
#             ('precip',   '75%'),
#             ('precip',   'max')],
#            )

# %%
# Drop a level so there is only one index
precip_by_season.columns = precip_by_season.columns.droplevel(0)
precip_by_season
# Out:
#          count      mean       std   min    25%   50%    75%   max
# seasons
# Fall       3.0  1.513333  0.285715  1.31  1.350  1.39  1.615  1.84
# Spring     3.0  2.610000  0.660908  1.85  2.390  2.93  2.990  3.05
# Summer     3.0  1.856667  0.209841  1.62  1.775  1.93  1.975  2.02
# Winter     3.0  0.763333  0.070946  0.70  0.725  0.75  0.795  0.84

# %%
# Plot the data
f, ax = plt.subplots()

ax.bar(precip_by_season.index,
        precip_by_season["mean"],
        color="purple")

ax.set(title="Bar Plot of Seasonal Monthly Precipitation in mm")
plt.show()

# %%
# Save median of precip for each season to dataframe
avg_monthly_precip_median = avg_monthly_precip.groupby(
    ["seasons"])[["precip"]].median()

avg_monthly_precip_median
# Out:
#          precip
# seasons
# Fall       1.39
# Spring     2.93
# Summer     1.93
# Winter     0.75

# %%
avg_monthly_precip_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Fall to Winter
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   precip  4 non-null      float64
# dtypes: float64(1)
# memory usage: 64.0+ bytes

# %%
# Save to new dataframe with original index
avg_monthly_precip_median = avg_monthly_precip.groupby(
    ["seasons"], as_index=False)[["precip"]].median()

avg_monthly_precip_median
# Out:
#   seasons  precip
# 0    Fall    1.39
# 1  Spring    2.93
# 2  Summer    1.93
# 3  Winter    0.75

# %%
# Save summary stats of precip for each season to dataframe
avg_monthly_precip_stats = avg_monthly_precip.groupby(
    ["seasons"])[["precip"]].describe()

avg_monthly_precip_stats
# Out:
#         precip
#          count      mean       std   min    25%   50%    75%   max
# seasons
# Fall       3.0  1.513333  0.285715  1.31  1.350  1.39  1.615  1.84
# Spring     3.0  2.610000  0.660908  1.85  2.390  2.93  2.990  3.05
# Summer     3.0  1.856667  0.209841  1.62  1.775  1.93  1.975  2.02
# Winter     3.0  0.763333  0.070946  0.70  0.725  0.75  0.795  0.84

# %%
# Reset index
avg_monthly_precip_stats.reset_index(inplace=True)

avg_monthly_precip_stats
# Out:
#   seasons precip
#            count      mean       std   min    25%   50%    75%   max
# 0    Fall    3.0  1.513333  0.285715  1.31  1.350  1.39  1.615  1.84
# 1  Spring    3.0  2.610000  0.660908  1.85  2.390  2.93  2.990  3.05
# 2  Summer    3.0  1.856667  0.209841  1.62  1.775  1.93  1.975  2.02
# 3  Winter    3.0  0.763333  0.070946  0.70  0.725  0.75  0.795  0.84
